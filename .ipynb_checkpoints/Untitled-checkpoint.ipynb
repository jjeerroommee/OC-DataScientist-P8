# %%
import streamlit as st
import time
import numpy as np
import pandas as pd

# %%
st.set_page_config(page_title="Prêt à dépenser", page_icon="💰")

st.markdown("# Plotting Demo")
st.sidebar.header("Demande de crédit")
# Out:
# 2024-05-31 18:31:04.247
# ...
#   command:
#
#     streamlit run C:\Applications\Anaconda\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator(_root_container=1, _parent=DeltaGenerator())

# %%
def load_data() :
    # Load customers features as saved in .csv file thanks to a previous notebook
    clients = pd.read_csv("project/data/clients.csv", sep=";")
    
    # Use the line number as an ID for each customer
    clients['ID'] = clients.index
    
    # Move the ID column at 1st position in dataframe
    clients = clients[clients.columns.insert(0, 'ID')[:-1]]
    
    return clients

# %%
clients = load_data()

# %%
clients.head()
# Out:
#    ID  EXT_SOURCE_3  EXT_SOURCE_2  EXT_SOURCE_1  CODE_GENDER  DAYS_EMPLOYED  \
# 0   0      0.159520      0.789654      0.752614          0.0        -2329.0
# 1   1      0.432962      0.291656      0.564990          1.0        -4469.0
# 2   2      0.610991      0.699787           NaN          1.0        -4458.0
# 3   3      0.612704      0.509677      0.525734          0.0        -1866.0
# 4   4           NaN      0.425687      0.202145          1.0        -2191.0
#
#    INSTAL_DPD_MAX  NAME_FAMILY_STATUS_Married  \
# 0            11.0                         1.0
# 1             1.0                         1.0
# 2            21.0                         1.0
# 3             7.0                         1.0
# 4             0.0                         1.0
#
#    REFUSED_HOUR_APPR_PROCESS_START_MIN  PAYMENT_RATE  ...  \
# 0                                  NaN      0.036147  ...
# 1                                  NaN      0.077973  ...
# ...

# %%
colonnes = clients.columns.to_list()

# %%
for c in colonnes : clients = clients[['ID'].append(colonnes)]

# %%
z=clients.columns.insert(0, 'ID')

# %%
z[:-1]
# Out:
# Index(['ID', 'ID', 'EXT_SOURCE_3', 'EXT_SOURCE_2', 'EXT_SOURCE_1',
#        'CODE_GENDER', 'DAYS_EMPLOYED', 'INSTAL_DPD_MAX',
#        'NAME_FAMILY_STATUS_Married', 'REFUSED_HOUR_APPR_PROCESS_START_MIN',
#        ...
#        'CC_CNT_INSTALMENT_MATURE_CUM_MEAN', 'PREV_CODE_REJECT_REASON_HC_MEAN',
#        'CLOSED_DAYS_CREDIT_ENDDATE_MAX', 'BURO_AMT_CREDIT_SUM_MEAN',
#        'ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN', 'INSTAL_PAYMENT_DIFF_VAR',
#        'PREV_NAME_GOODS_CATEGORY_Mobile_MEAN',
#        'WEEKDAY_APPR_PROCESS_START_FRIDAY', 'PREV_AMT_ANNUITY_MAX',
#        'CC_MONTHS_BALANCE_VAR'],
#       dtype='object', length=142)

# %%
# Out:
#           ID  EXT_SOURCE_3  EXT_SOURCE_2  EXT_SOURCE_1  CODE_GENDER  \
# 0          0      0.159520      0.789654      0.752614          0.0
# 1          1      0.432962      0.291656      0.564990          1.0
# 2          2      0.610991      0.699787           NaN          1.0
# 3          3      0.612704      0.509677      0.525734          0.0
# 4          4           NaN      0.425687      0.202145          1.0
# ...      ...           ...           ...           ...          ...
# 48739  48739      0.643026      0.648575           NaN          0.0
# 48740  48740           NaN      0.684596           NaN          0.0
# 48741  48741      0.283712      0.632770      0.733503          0.0
# 48742  48742      0.595456      0.445701      0.373090          1.0
# 48743  48743      0.272134      0.456541           NaN          0.0
#
#        DAYS_EMPLOYED  INSTAL_DPD_MAX  NAME_FAMILY_STATUS_Married  \
# 0            -2329.0            11.0                         1.0
# ...

# %%
colonnes
# Out:
# ['ID',
#  'EXT_SOURCE_3',
#  'EXT_SOURCE_2',
#  'EXT_SOURCE_1',
#  'CODE_GENDER',
#  'DAYS_EMPLOYED',
#  'INSTAL_DPD_MAX',
#  'NAME_FAMILY_STATUS_Married',
#  'REFUSED_HOUR_APPR_PROCESS_START_MIN',
#  'PAYMENT_RATE',
#  'FLAG_OWN_CAR',
#  'PREV_RATE_DOWN_PAYMENT_MAX',
#  'POS_COUNT',
#  'NAME_INCOME_TYPE_Working',
#  'POS_SK_DPD_DEF_MAX',
#  'ANNUITY_INCOME_PERC',
#  'CC_CNT_DRAWINGS_CURRENT_VAR',
#  'BURO_STATUS_X_MEAN_MEAN',
#  'APPROVED_DAYS_DECISION_MIN',
#  'BURO_CREDIT_ACTIVE_Closed_MEAN',
#  'INSTAL_PAYMENT_PERC_SUM',
#  'ACTIVE_DAYS_CREDIT_MAX',
#  'FLAG_DOCUMENT_3',
#  'APPROVED_CNT_PAYMENT_MEAN',
#  'DAYS_EMPLOYED_PERC',
#  'CNT_CHILDREN',
#  'AMT_ANNUITY',
#  'REGION_RATING_CLIENT',
#  'OCCUPATION_TYPE_nan',
#  'FLAG_PHONE',
#  'REFUSED_APP_CREDIT_PERC_MIN',
#  'PREV_CNT_PAYMENT_MEAN',
#  'PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN',
#  'PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN',
#  'POS_NAME_CONTRACT_STATUS_Active_MEAN',
#  'APPROVED_AMT_DOWN_PAYMENT_MAX',
# ...

# %%
z='ID'
z.append(colonnes)
z
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 2
#       1 z='ID'
# ----> 2 z.append(colonnes)
#       3 z
#
# AttributeError: 'str' object has no attribute 'append'

# %%
clients[z]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 clients[z]
#
# File C:\Applications\Anaconda\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File C:\Applications\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:6110, in Index._get_indexer_strict(self, key, axis_name)
#    6107     keyarr = com.asarray_tuplesafe(keyarr)
#    6109 if self._index_as_unique:
# -> 6110     indexer = self.get_indexer_for(keyarr)
#    6111     keyarr = self.reindex(keyarr)[0]
#    6112 else:
#
# ...

# %%
type(z)
# Out:
# list

# %%
clients.head()
# Out:
#    EXT_SOURCE_3  EXT_SOURCE_2  EXT_SOURCE_1  CODE_GENDER  DAYS_EMPLOYED  \
# 0      0.159520      0.789654      0.752614          0.0        -2329.0
# 1      0.432962      0.291656      0.564990          1.0        -4469.0
# 2      0.610991      0.699787           NaN          1.0        -4458.0
# 3      0.612704      0.509677      0.525734          0.0        -1866.0
# 4           NaN      0.425687      0.202145          1.0        -2191.0
#
#    INSTAL_DPD_MAX  NAME_FAMILY_STATUS_Married  \
# 0            11.0                         1.0
# 1             1.0                         1.0
# 2            21.0                         1.0
# 3             7.0                         1.0
# 4             0.0                         1.0
#
#    REFUSED_HOUR_APPR_PROCESS_START_MIN  PAYMENT_RATE  FLAG_OWN_CAR  ...  \
# 0                                  NaN      0.036147           0.0  ...
# 1                                  NaN      0.077973           0.0  ...
# ...
